# %% [markdown]
# <a href="https://colab.research.google.com/github/Suryaanugrah2001/EDA-Kematian-Israel-Palestina/blob/main/EDA_Kematian_Israel_Palestina_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import files
df = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/kematianispal.csv")
df
# Out:
#                                               name date_of_event   age  \
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
# 11123                            Wichlav Zalsevsky    2000-10-02  24.0
#
#        citizenship     event_location event_location_district  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                               name date_of_event   age  \
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
# 11123                            Wichlav Zalsevsky    2000-10-02  24.0
#
#        citizenship     event_location event_location_district  \
# ...

# %%
df.describe()
# Out:
#                 age
# count  10995.000000
# mean      26.745703
# std       13.780548
# min        1.000000
# 25%       19.000000
# 50%       23.000000
# 75%       31.000000
# max      112.000000

# %%
df.isna().sum()
# Out:
# name                               0
# date_of_event                      0
# age                              129
# citizenship                        0
# event_location                     0
# event_location_district            0
# event_location_region              0
# date_of_death                      0
# gender                            20
# took_part_in_the_hostilities    1430
# place_of_residence                68
# place_of_residence_district       68
# type_of_injury                   291
# ammunition                      5253
# killed_by                          0
# notes                            280
# dtype: int64

# %%
# grafik darikolom umur
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], bins=20, kde=True)
plt.title('Persentase Umur')
plt.xlabel('Umur')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Dapat Dilhat dari histogram diatas banyaknya kematian dari konflik israel palestina berada di **umur 20 tahun yang mencapai >3000 Jiwa**

# %%
#Grafik dari gender
gender_counts = df['gender'].value_counts()
plt.figure(figsize=(8, 6))
sns.barplot(x=gender_counts.index, y=gender_counts.values)
plt.title('Persentase Jenis Kelamin')
plt.xlabel('Jenis Kelamin')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# Dapat Dilhat dari plot diatas banyaknya kematian dari konflik israel palestina berada di **adalah Pria dengan jumlah sekitar 9000 jiwa**

# %%
#Plot bar untuk 'kewarganegaraan'
citizenship_counts = df['citizenship'].value_counts()
plt.figure(figsize=(12, 6))
sns.barplot(x=citizenship_counts.index, y=citizenship_counts.values)
plt.title('Persentasi Kewarganegaraan')
plt.xlabel('Kewarganegaraan')
plt.ylabel('Jumlah')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Dapat Dilhat dari plot diatas banyaknya kematian dari konflik israel palestina berada di negara **palestina**

# %%
#  Histogram untuk kolom 'ikut serta dalam permusuhan'
plt.figure(figsize=(10, 6))
sns.histplot(df['took_part_in_the_hostilities'], bins=20, kde=False)
plt.title('Persentase Permusuhan')
plt.ylabel('Frekuensi')
plt.show()

# %%
df['date_of_event'] = pd.to_datetime(df['date_of_event'])
df['date_of_death'] = pd.to_datetime(df['date_of_death'])

# %%
# Menghitung jumlah kejadian per hari
events_per_day = df.groupby('date_of_event').size()

plt.figure(figsize=(12, 6))
events_per_day.plot()
plt.title('Peristiwa Seiring Waktu')
plt.xlabel('Tanggal kejadian')
plt.ylabel('Jumlah Kejadian')
plt.show()

# %%
events_by_killed_by = df.groupby(['date_of_event', 'killed_by']).size().unstack().fillna(0)

plt.figure(figsize=(12, 6))
for column in events_by_killed_by.columns:
    plt.plot(events_by_killed_by.index, events_by_killed_by[column], label=column)

plt.title('Jumlah Peristiwa Seiring Waktu menurut "killed_by"')
plt.xlabel('Tanggal Kejadian')
plt.ylabel('Jumlah Kejadian')
plt.legend(loc='upper right', fontsize='small')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Dari Grafik diatas kejadian pembunuhan banyak dilakukan oleh pasukan keamanan Israel**

# %%
#Mengelompokkan kolom 'date_of_event' dan 'ammunition' serta menghitung jumlah kejadian untuk setiap kombinasi

events_by_ammunition = df.groupby(['date_of_event', 'ammunition']).size().unstack().fillna(0)

plt.figure(figsize=(12, 6))
for column in events_by_ammunition.columns:
    plt.plot(events_by_ammunition.index, events_by_ammunition[column], label=column)

plt.title('Jumlah Kejadian Sepanjang Waktu berdasarkan "Amunisi"')
plt.xlabel('Tanggal Kejadian')
plt.ylabel('Jumlah Kejadian')
plt.legend(loc='upper right', fontsize='small')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Amunisi terbanyak yang dipakai pada kejadian adalah **roket qassam** dengan rentan kejadian pada 2008-2009
# dan untuk kejadian akhir akhir ini kebanyakan amunisi yang dipakai adalah **tabung gas air mata dan juga misil**

# %%
#Top 5 jumlah lokasi kejadian
top5_event_locations = df['event_location'].value_counts().head(5)

plt.figure(figsize=(12, 6))
sns.barplot(x=top5_event_locations.index, y=top5_event_locations.values)
plt.title('Top 5 jumlah lokasi kejadian')
plt.xlabel('Lokasi Kejadian')
plt.ylabel('Jumlah')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Kejadian konflik israel palestina banyak terjadi di wilayah **kota gaza dan rafah**
# dimana Rafah kota di Palestina yang terletak di Jalur Gaza
# dan Kota gaza yang juga disebut sebagai Kota Gaza, adalah sebuah kota Palestina di Jalur Gaza, dengan populasi 515,556, menjadikannya kota terbesar di Negara Palestina

# %%
#Top 5 tempat tinggal teratas
top5_place_of_residence = df['place_of_residence'].value_counts().head(5)

plt.figure(figsize=(12, 6))
sns.barplot(x=top5_place_of_residence.index, y=top5_place_of_residence.values)
plt.title('5 Tempat Tinggal Teratas menurut Hitungan')
plt.xlabel('Tempat Tinggal')
plt.ylabel('Jumlah')
plt.xticks(rotation=90)
plt.show()

# %%
#tempat tinggal
place_of_residence_district = df['place_of_residence_district'].value_counts()

plt.figure(figsize=(12, 6))
sns.barplot(x=place_of_residence_district.index, y=place_of_residence_district.values)
plt.title('Distrik tempat tinggal')
plt.xlabel('Daerah Tempat Tinggal')
plt.ylabel('Jumlah')
plt.xticks(rotation=90)
plt.show()

# %%
#Plot  untuk 'jenis cedera'
type_of_injury_counts = df['type_of_injury'].value_counts()
plt.figure(figsize=(12, 6))
sns.barplot(x=type_of_injury_counts.index, y=type_of_injury_counts.values)
plt.title('Persentase Jenis Cedera')
plt.xlabel('Jenis Cedera')
plt.ylabel('Jumlah')
plt.xticks(rotation=90)
plt.show()

# %%
top5_ammunition_counts = df['ammunition'].value_counts().head(5)
plt.figure(figsize=(12, 6))
sns.barplot(x=top5_ammunition_counts.index, y=top5_ammunition_counts.values)
plt.title('Persentase Top 5 Amunisi')
plt.xlabel('Ammunisi')
plt.ylabel('Jumlah')
plt.xticks(rotation=90)
plt.show()

# %%
killed_by_counts = df['killed_by'].value_counts()
plt.figure(figsize=(12, 6))
sns.barplot(x=killed_by_counts.index, y=killed_by_counts.values)
plt.title('Persentase Jumlah Kematian')
plt.xlabel('Mati Karena')
plt.ylabel('Jumlah')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Distribusi Usia:** Usia keamatian bervariasi secara luas, dengan usia rata-rata sekitar 26,44 tahun. Mayoritas individu berada dalam rentang usia 19-31 tahun.
#
# **Distribusi Gender:** jumlah korban laki-laki yang lebih tinggi dibandingkan perempuan.
#
# **Distribusi Kewarganegaraan:** Warga Palestina lebih banyak dibandingkan warga Israel dalam dataset, menunjukkan jumlah korban Palestina yang lebih tinggi.
#
# **Keterlibatan dalam Hostilitas:** Lebih dari 4000 individu tidak terlibat dalam hostilitas, sementara lebih dari 3000 tapi kurang dari 4000 terlibat. Sekitar 1000 korban adalah warga Israel, dan hampir 200 merupakan pembunuhan yang dijadwalkan. Ada juga 2000 yang tidak teridentifikasi.
#
# **Analisis Time Series:** Jumlah kejadian mencapai puncaknya pada tahun 2008-2009 dan kembali meningkat pada tahun 2015-2016.
#
# **Kejadian oleh Pasukan Keamanan Israel:** Jumlah kejadian yang melibatkan pasukan keamanan Israel cenderung meningkat pada tahun 2008-2009 dan kembali pada tahun 2015.
#
# **Distribusi Amunisi:** Sebagian besar kejadian melibatkan senjata yang tidak teridentifikasi, diikuti oleh roket Qassam dan bom. Pada tahun 2015, roket dan misil Grad juga digunakan.
#
# **Analisis Geopolitik:** Lima lokasi kejadian teratas adalah Kota Gaza, Rafah, Khan Yunis, Jabalya RC, dan Beit Lahiya, dengan Kota Gaza memiliki jumlah terbanyak.
#
# **Analisis Tempat Tinggal:** Distribusi tempat tinggal mencerminkan lokasi kejadian, dengan Kota Gaza menjadi prominent.
#
# **Jumlah yang Dibunuh:** Pasukan keamanan Israel bertanggung jawab atas sejumlah besar korban, sementara warga sipil Palestina bertanggung jawab atas jumlah yang lebih sedikit.
